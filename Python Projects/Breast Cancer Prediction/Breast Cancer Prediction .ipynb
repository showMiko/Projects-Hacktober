# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,accuracy_score,f1_score,r2_score
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("data.csv")

# %%
df.set_index('id', inplace=True)

# %%
df.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  texture_worst  \
# id                                            ...
# 842302                0.14710         0.2419  ...          17.33
# 842517                0.07017         0.1812  ...          23.41
# 84300903              0.12790         0.2069  ...          25.53
# 84348301              0.10520         0.2597  ...          26.50
# 84358402              0.10430         0.1809  ...          16.67
#
#           perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# id
# 842302             184.60      2019.0            0.1622             0.6656
# 842517             158.80      1956.0            0.1238             0.1866
# 84300903           152.50      1709.0            0.1444             0.4245
# 84348301            98.87       567.7            0.2098             0.8663
# 84358402           152.20      1575.0            0.1374             0.2050
#
#           concavity_worst  concave points_worst  symmetry_worst  \
# id
# 842302             0.7119                0.2654          0.4601
# 842517             0.2416                0.1860          0.2750
# 84300903           0.4504                0.2430          0.3613
# 84348301           0.6869                0.2575          0.6638
# 84358402           0.4000                0.1625          0.2364
#
#           fractal_dimension_worst  Unnamed: 32
# id
# 842302                    0.11890          NaN
# 842517                    0.08902          NaN
# 84300903                  0.08758          NaN
# 84348301                  0.17300          NaN
# 84358402                  0.07678          NaN
#
# [5 rows x 32 columns]

# %%
df.describe().style.background_gradient(cmap = "Reds")
# Out:
# <style type="text/css">
# #T_6e676_row0_col0, #T_6e676_row0_col1, #T_6e676_row0_col2, #T_6e676_row0_col4, #T_6e676_row0_col5, #T_6e676_row0_col6, #T_6e676_row0_col7, #T_6e676_row0_col8, #T_6e676_row0_col9, #T_6e676_row0_col10, #T_6e676_row0_col11, #T_6e676_row0_col12, #T_6e676_row0_col13, #T_6e676_row0_col14, #T_6e676_row0_col15, #T_6e676_row0_col16, #T_6e676_row0_col17, #T_6e676_row0_col18, #T_6e676_row0_col19, #T_6e676_row0_col20, #T_6e676_row0_col21, #T_6e676_row0_col22, #T_6e676_row0_col24, #T_6e676_row0_col25, #T_6e676_row0_col26, #T_6e676_row0_col27, #T_6e676_row0_col28, #T_6e676_row0_col29, #T_6e676_row7_col3, #T_6e676_row7_col23 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_6e676_row0_col3 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_6e676_row0_col23, #T_6e676_row2_col23, #T_6e676_row4_col22 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_6e676_row0_col30, #T_6e676_row1_col4, #T_6e676_row1_col5, #T_6e676_row1_col6, #T_6e676_row1_col7, #T_6e676_row1_col8, #T_6e676_row1_col9, #T_6e676_row1_col10, #T_6e676_row1_col11, #T_6e676_row1_col12, #T_6e676_row1_col14, #T_6e676_row1_col15, #T_6e676_row1_col16, #T_6e676_row1_col17, #T_6e676_row1_col18, #T_6e676_row1_col19, #T_6e676_row1_col24, #T_6e676_row1_col25, #T_6e676_row1_col26, #T_6e676_row1_col27, #T_6e676_row1_col28, #T_6e676_row1_col29, #T_6e676_row1_col30, #T_6e676_row2_col0, #T_6e676_row2_col1, #T_6e676_row2_col2, #T_6e676_row2_col4, #T_6e676_row2_col5, #T_6e676_row2_col6, #T_6e676_row2_col7, #T_6e676_row2_col8, #T_6e676_row2_col9, #T_6e676_row2_col10, #T_6e676_row2_col11, #T_6e676_row2_col12, #T_6e676_row2_col14, #T_6e676_row2_col15, #T_6e676_row2_col16, #T_6e676_row2_col17, #T_6e676_row2_col18, #T_6e676_row2_col19, #T_6e676_row2_col20, #T_6e676_row2_col21, #T_6e676_row2_col22, #T_6e676_row2_col24, #T_6e676_row2_col25, #T_6e676_row2_col26, #T_6e676_row2_col27, #T_6e676_row2_col28, #T_6e676_row2_col29, #T_6e676_row2_col30, #T_6e676_row3_col3, #T_6e676_row3_col4, #T_6e676_row3_col5, #T_6e676_row3_col6, #T_6e676_row3_col7, #T_6e676_row3_col8, #T_6e676_row3_col9, #T_6e676_row3_col10, #T_6e676_row3_col11, #T_6e676_row3_col12, #T_6e676_row3_col13, #T_6e676_row3_col14, #T_6e676_row3_col15, #T_6e676_row3_col16, #T_6e676_row3_col17, #T_6e676_row3_col18, #T_6e676_row3_col19, #T_6e676_row3_col23, #T_6e676_row3_col24, #T_6e676_row3_col25, #T_6e676_row3_col26, #T_6e676_row3_col27, #T_6e676_row3_col28, #T_6e676_row3_col29, #T_6e676_row3_col30, #T_6e676_row4_col4, #T_6e676_row4_col5, #T_6e676_row4_col6, #T_6e676_row4_col7, #T_6e676_row4_col8, #T_6e676_row4_col9, #T_6e676_row4_col10, #T_6e676_row4_col11, #T_6e676_row4_col12, #T_6e676_row4_col14, #T_6e676_row4_col15, #T_6e676_row4_col16, #T_6e676_row4_col17, #T_6e676_row4_col18, #T_6e676_row4_col19, #T_6e676_row4_col24, #T_6e676_row4_col25, #T_6e676_row4_col26, #T_6e676_row4_col27, #T_6e676_row4_col28, #T_6e676_row4_col29, #T_6e676_row4_col30, #T_6e676_row5_col4, #T_6e676_row5_col5, #T_6e676_row5_col6, #T_6e676_row5_col7, #T_6e676_row5_col8, #T_6e676_row5_col9, #T_6e676_row5_col10, #T_6e676_row5_col11, #T_6e676_row5_col12, #T_6e676_row5_col14, #T_6e676_row5_col15, #T_6e676_row5_col16, #T_6e676_row5_col17, #T_6e676_row5_col18, #T_6e676_row5_col19, #T_6e676_row5_col24, #T_6e676_row5_col25, #T_6e676_row5_col26, #T_6e676_row5_col27, #T_6e676_row5_col28, #T_6e676_row5_col29, #T_6e676_row5_col30, #T_6e676_row6_col4, #T_6e676_row6_col5, #T_6e676_row6_col6, #T_6e676_row6_col7, #T_6e676_row6_col8, #T_6e676_row6_col9, #T_6e676_row6_col10, #T_6e676_row6_col11, #T_6e676_row6_col14, #T_6e676_row6_col15, #T_6e676_row6_col16, #T_6e676_row6_col17, #T_6e676_row6_col18, #T_6e676_row6_col19, #T_6e676_row6_col24, #T_6e676_row6_col25, #T_6e676_row6_col26, #T_6e676_row6_col27, #T_6e676_row6_col28, #T_6e676_row6_col29, #T_6e676_row6_col30, #T_6e676_row7_col4, #T_6e676_row7_col5, #T_6e676_row7_col6, #T_6e676_row7_col7, #T_6e676_row7_col8, #T_6e676_row7_col9, #T_6e676_row7_col14, #T_6e676_row7_col15, #T_6e676_row7_col16, #T_6e676_row7_col17, #T_6e676_row7_col18, #T_6e676_row7_col19, #T_6e676_row7_col24, #T_6e676_row7_col25, #T_6e676_row7_col26, #T_6e676_row7_col27, #T_6e676_row7_col28, #T_6e676_row7_col29, #T_6e676_row7_col30 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_6e676_row1_col0, #T_6e676_row5_col0, #T_6e676_row5_col20 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_6e676_row1_col1, #T_6e676_row4_col21, #T_6e676_row5_col1, #T_6e676_row6_col20 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_6e676_row1_col2, #T_6e676_row5_col23 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_6e676_row1_col3 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_6e676_row1_col13, #T_6e676_row7_col1 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_6e676_row1_col20, #T_6e676_row4_col1, #T_6e676_row4_col13, #T_6e676_row6_col0 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_6e676_row1_col21, #T_6e676_row3_col22, #T_6e676_row5_col13, #T_6e676_row5_col21 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_6e676_row1_col22 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_6e676_row1_col23, #T_6e676_row6_col22 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_6e676_row2_col3 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_6e676_row2_col13, #T_6e676_row6_col13 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_6e676_row3_col0, #T_6e676_row3_col20, #T_6e676_row6_col12, #T_6e676_row7_col10 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_6e676_row3_col1, #T_6e676_row3_col21, #T_6e676_row7_col11 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_6e676_row3_col2, #T_6e676_row7_col12 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_6e676_row4_col0, #T_6e676_row4_col20 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_6e676_row4_col2 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_6e676_row4_col3, #T_6e676_row5_col22 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_6e676_row4_col23 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_6e676_row5_col2 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_6e676_row5_col3 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_6e676_row6_col1 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_6e676_row6_col2 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_6e676_row6_col3 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_6e676_row6_col21 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_6e676_row6_col23 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_6e676_row7_col0 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_6e676_row7_col2 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_6e676_row7_col13 {
#   background-color: #7e0610;
#   color: #f1f1f1;
# }
# #T_6e676_row7_col20 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_6e676_row7_col21 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_6e676_row7_col22 {
#   background-color: #fc8767;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6e676">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e676_level0_col0" class="col_heading level0 col0" >radius_mean</th>
#       <th id="T_6e676_level0_col1" class="col_heading level0 col1" >texture_mean</th>
#       <th id="T_6e676_level0_col2" class="col_heading level0 col2" >perimeter_mean</th>
#       <th id="T_6e676_level0_col3" class="col_heading level0 col3" >area_mean</th>
#       <th id="T_6e676_level0_col4" class="col_heading level0 col4" >smoothness_mean</th>
#       <th id="T_6e676_level0_col5" class="col_heading level0 col5" >compactness_mean</th>
#       <th id="T_6e676_level0_col6" class="col_heading level0 col6" >concavity_mean</th>
#       <th id="T_6e676_level0_col7" class="col_heading level0 col7" >concave points_mean</th>
#       <th id="T_6e676_level0_col8" class="col_heading level0 col8" >symmetry_mean</th>
#       <th id="T_6e676_level0_col9" class="col_heading level0 col9" >fractal_dimension_mean</th>
#       <th id="T_6e676_level0_col10" class="col_heading level0 col10" >radius_se</th>
#       <th id="T_6e676_level0_col11"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 569 entries, 842302 to 92751
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
#  13  perimeter_se             569 non-null    float64
#  14  area_se                  569 non-null    float64
#  15  smoothness_se            569 non-null    float64
#  16  compactness_se           569 non-null    float64
#  17  concavity_se             569 non-null    float64
#  18  concave points_se        569 non-null    float64
#  19  symmetry_se              569 non-null    float64
#  20  fractal_dimension_se     569 non-null    float64
#  21  radius_worst             569 non-null    float64
#  22  texture_worst            569 non-null    float64
#  23  perimeter_worst          569 non-null    float64
#  24  area_worst               569 non-null    float64
#  25  smoothness_worst         569 non-null    float64
#  26  compactness_worst        569 non-null    float64
#  27  concavity_worst          569 non-null    float64
#  28  concave points_worst     569 non-null    float64
#  29  symmetry_worst           569 non-null    float64
#  30  fractal_dimension_worst  569 non-null    float64
#  31  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), object(1)
# memory usage: 146.7+ KB

# %%
df.isna().sum()
# Out:
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
df.drop(["Unnamed: 32"],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
plt.scatter(x=df["radius_mean"],y=df["perimeter_mean"])

# %%
plt.figure(figsize=(25,20)) 
sns.heatmap(df.corr(),annot=True,cmap="Blues")
# Out:
# C:\Users\malak\AppData\Local\Temp\ipykernel_20348\2253818768.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap="Blues")
# <AxesSubplot: >

# %%
df.hist(figsize=(30,20))
plt.show()

# %%
df["diagnosis"].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
encoder = LabelEncoder()
df['diagnosis'] = encoder.fit_transform(df['diagnosis'])
diagnosis = {index : label for index, label in enumerate(encoder.classes_)}

# %%
# sns.countplot('diagnosis', data=df); #1=M,0=B
# plt.show()

# %%
X=df.drop(columns=["diagnosis"])
y=df["diagnosis"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.3,random_state=42)

# %%
log=LogisticRegression(max_iter=100,solver="newton-cg")#{'newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'} default='lbfgs'
log.fit(X_train,y_train)
y_pred2=log.predict(X_test)

# %%
pd.DataFrame({"actual " :y_test,"prediction:": y_pred2})
CM2 = confusion_matrix(y_test, y_pred2)
print(CM2)
F1Score2 = f1_score(y_test, y_pred2, average='micro')
print('F1 Score is : ', F1Score2)
# Out:
# [[106   2]
#  [  2  61]]
# F1 Score is :  0.9766081871345029
